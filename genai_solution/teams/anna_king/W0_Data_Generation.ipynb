# %% [markdown]
# # Session X: Email Generation
#
# Ideally, we want a set of email queries that we can answer with our dataset.
# This is the code used to generate order status emails.
# You can adapt this code to make other types also.

# %%
# # Install pandas, openai if you dont already have it
# !pip install pandas openai
# Out:
# Requirement already satisfied: pandas in c:\users\annak\onedrive\documents\github\data_science_ai_workshop_series\.conda\lib\site-packages (2.2.3)
# Requirement already satisfied: openai in c:\users\annak\onedrive\documents\github\data_science_ai_workshop_series\.conda\lib\site-packages (1.65.4)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\annak\onedrive\documents\github\data_science_ai_workshop_series\.conda\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\annak\onedrive\documents\github\data_science_ai_workshop_series\.conda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\annak\onedrive\documents\github\data_science_ai_workshop_series\.conda\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\annak\onedrive\documents\github\data_science_ai_workshop_series\.conda\lib\site-packages (from pandas) (2025.1)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\annak\onedrive\documents\github\data_science_ai_workshop_series\.conda\lib\site-packages (from openai) (4.6.2.post1)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\annak\onedrive\documents\github\data_science_ai_workshop_series\.conda\lib\site-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\annak\onedrive\documents\github\data_science_ai_workshop_series\.conda\lib\site-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in c:\users\annak\onedrive\documents\github\data_science_ai_workshop_series\.conda\lib\site-packages (from openai) (0.8.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\annak\onedrive\documents\github\data_science_ai_workshop_series\.conda\lib\site-packages (from openai) (2.10.6)
# Requirement already satisfied: sniffio in c:\users\annak\onedrive\documents\github\data_science_ai_workshop_series\.conda\lib\site-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in c:\users\annak\onedrive\documents\github\data_science_ai_workshop_series\.conda\lib\site-packages (from openai) (4.67.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in c:\users\annak\onedrive\documents\github\data_science_ai_workshop_series\.conda\lib\site-packages (from openai) (4.12.2)
# Requirement already satisfied: idna>=2.8 in c:\users\annak\onedrive\documents\github\data_science_ai_workshop_series\.conda\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: certifi in c:\users\annak\onedrive\documents\github\data_science_ai_workshop_series\.conda\lib\site-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in c:\users\annak\onedrive\documents\github\data_science_ai_workshop_series\.conda\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.6)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\annak\onedrive\documents\github\data_science_ai_workshop_series\.conda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\annak\onedrive\documents\github\data_science_ai_workshop_series\.conda\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\annak\onedrive\documents\github\data_science_ai_workshop_series\.conda\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.27.2)
# Requirement already satisfied: six>=1.5 in c:\users\annak\onedrive\documents\github\data_science_ai_workshop_series\.conda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: colorama in c:\users\annak\onedrive\documents\github\data_science_ai_workshop_series\.conda\lib\site-packages (from tqdm>4->openai) (0.4.6)

# %% [markdown]
# ## Load Data

# %%
import pandas as pd
import os
from dotenv import load_dotenv

load_dotenv()

OPENAI_API_KEY = os.getenv('OPENAI_API_KEY')

data_folder = os.getcwd().split("genai_solution")[0] + "genai_solution\\data\\"

# %%
from os import listdir
from os.path import isfile, join
onlyfiles = [f for f in listdir(data_folder) if isfile(join(data_folder, f))]

# %%
onlyfiles
# Out:
# ['.gitignore',
#  'image.png',
#  'new_retail_data.csv',
#  'olist_customers_dataset.csv',
#  'olist_geolocation_dataset.csv',
#  'olist_orders_dataset.csv',
#  'olist_order_items_dataset.csv',
#  'olist_order_payments_dataset.csv',
#  'olist_order_reviews_dataset.csv',
#  'olist_products_dataset.csv',
#  'olist_sellers_dataset.csv',
#  'order_status_emails.csv',
#  'product_category_name_translation.csv',
#  'README.md']

# %%
orders = pd.read_csv(data_folder + 'olist_orders_dataset.csv')  
orders.head()
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# 1          2018-07-26 14:31:00           2018-08-07 15:27:45
# 2          2018-08-08 13:50:00           2018-08-17 18:06:29
# 3          2017-11-22 13:39:59           2017-12-02 00:28:42
# 4          2018-02-14 19:46:34           2018-02-16 18:17:02
#
#   order_estimated_delivery_date
# 0           2017-10-18 00:00:00
# 1           2018-08-13 00:00:00
# 2           2018-09-04 00:00:00
# 3           2017-12-15 00:00:00
# 4           2018-02-26 00:00:00

# %%
order_items = pd.read_csv(data_folder + 'olist_order_items_dataset.csv')  
products = pd.read_csv(data_folder + 'olist_products_dataset.csv')  
product_name_translation = pd.read_csv(data_folder + 'product_category_name_translation.csv')  

order_items = order_items.merge(products, "left", on="product_id").merge(product_name_translation,"left", on="product_category_name")

# %%
customers = pd.read_csv(data_folder + 'olist_customers_dataset.csv')  
customers.head()
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %% [markdown]
# ## Define LLM connection

# %%
from openai import OpenAI
# add your OPENAI_API_KEY here

def query_open_ai(prompt, temperature=0.7):
    client = OpenAI(api_key=OPENAI_API_KEY)
    completions = client.chat.completions.create(
        model="gpt-4o",
        messages=[
            {
                "role": "system",
                "content": prompt
            }
        ],
        temperature=temperature
    )
 
    return completions.choices[0].message.content

# %% [markdown]
# I got the LLM to generate a list of potential email queries. I only order status is used in this example.

# %%
categories = {"Order-Related Issues":
["Order Status – Customers asking about the status of their orders (e.g., 'Where is my order?').",
"Order Modifications – Requests to change order details (e.g., address change, item swap).",
"Order Cancellations – Customers wanting to cancel an order before shipping."],
"Payment & Billing Issues":
["Payment Failures – Issues with processing payments.",
"Refund Requests – Customers requesting refunds for returned or undelivered items.",
"Incorrect Charges – Complaints about being overcharged or double charged."],
"Shipping & Delivery Issues":
["Delayed Delivery – Customers complaining about late shipments.",
"Lost or Missing Packages – Orders that haven’t arrived or are marked as delivered but not received.",
"Damaged Items – Complaints about receiving broken or defective products."],
"Returns & Exchanges":
["Return Requests – Customers asking how to return a product.",
"Exchange Requests – Requests to swap an item for another."],
"Product-Related Queries":
["Product Information – Questions about product specifications, availability, or compatibility.",
"Product Authenticity & Quality – Concerns about whether the product is genuine or meets expectations."],
"Technical Issues":
["Website or App Issues – Customers reporting glitches, login problems, or checkout failures.",
"Account Problems – Issues with logging in, password resets, or account security."],
"Seller-Related Complaints":
["Seller Responsiveness – Customers complaining about unresponsive sellers.",
"Seller Misrepresentation – Concerns about misleading product descriptions or pricing."],
"Promotions & Discounts":
["Promo Code Issues – Complaints about discount codes not working.",
"Price Adjustments – Requests for partial refunds due to price drops after purchase."],
"General Inquiries & Feedback":
["General Questions – Miscellaneous questions about policies, store operations, etc.",
"Customer Feedback & Complaints – Compliments, complaints, or improvement suggestions."]}

# %%
customers = customers.sample(frac=1).reset_index(drop=True)

# %% [markdown]
# ## Order status Emails

# %% [markdown]
# I got the LLM to generate a list of names and emails for use in the email generation.

# %%
customer_name_email = [
{ "name": "John Smith", "email": "john.smith@gmail.com" },
{ "name": "Jane Doe", "email": "jane.doe@yahoo.com" },
{ "name": "Alice Johnson", "email": "alice.johnson@outlook.com" },
{ "name": "Robert Brown", "email": "robert.brown@gmail.com" },
{ "name": "Emily Davis", "email": "emily.davis@hotmail.com" },
{ "name": "Michael Wilson", "email": "michael.wilson@yahoo.com" },
{ "name": "Sarah Martinez", "email": "sarah.martinez@gmail.com" },
{ "name": "David Anderson", "email": "david.anderson@icloud.com" },
{ "name": "Emma Thomas", "email": "emma.thomas@aol.com" },
{ "name": "James White", "email": "james.white@outlook.com" },
{ "name": "Olivia Harris", "email": "olivia.harris@gmail.com" },
{ "name": "William Martin", "email": "william.martin@yahoo.com" },
{ "name": "Sophia Thompson", "email": "sophia.thompson@hotmail.com" },
{ "name": "Benjamin Garcia", "email": "benjamin.garcia@icloud.com" },
{ "name": "Charlotte Martinez", "email": "charlotte.martinez@gmail.com" },
{ "name": "Daniel Robinson", "email": "daniel.robinson@outlook.com" },
{ "name": "Mia Clark", "email": "mia.clark@yahoo.com" },
{ "name": "Lucas Rodriguez", "email": "lucas.rodriguez@gmail.com" },
{ "name": "Amelia Lewis", "email": "amelia.lewis@icloud.com" },
{ "name": "Henry Walker", "email": "henry.walker@outlook.com" },
{ "name": "Evelyn Hall", "email": "evelyn.hall@gmail.com" },
{ "name": "Alexander Allen", "email": "alexander.allen@hotmail.com" },
{ "name": "Harper Young", "email": "harper.young@yahoo.com" },
{ "name": "Elijah King", "email": "elijah.king@gmail.com" },
{ "name": "Isabella Wright", "email": "isabella.wright@icloud.com" },
{ "name": "Sebastian Scott", "email": "sebastian.scott@aol.com" },
{ "name": "Avery Green", "email": "avery.green@yahoo.com" },
{ "name": "Jack Adams", "email": "jack.adams@gmail.com" },
{ "name": "Lily Nelson", "email": "lily.nelson@outlook.com" },
{ "name": "Matthew Baker", "email": "matthew.baker@hotmail.com" },
{ "name": "Scarlett Gonzalez", "email": "scarlett.gonzalez@yahoo.com" },
{ "name": "Joseph Carter", "email": "joseph.carter@gmail.com" },
{ "name": "Chloe Perez", "email": "chloe.perez@icloud.com" },
{ "name": "Samuel Turner", "email": "samuel.turner@hotmail.com" },
{ "name": "Zoey Collins", "email": "zoey.collins@yahoo.com" },
{ "name": "David Edwards", "email": "david.edwards@gmail.com" },
{ "name": "Ella Stewart", "email": "ella.stewart@aol.com" },
{ "name": "Gabriel Flores", "email": "gabriel.flores@outlook.com" },
{ "name": "Aria Morris", "email": "aria.morris@gmail.com" },
{ "name": "Nathaniel Rivera", "email": "nathaniel.rivera@icloud.com" },
{ "name": "Penelope Cooper", "email": "penelope.cooper@hotmail.com" },
{ "name": "Andrew Reed", "email": "andrew.reed@yahoo.com" },
{ "name": "Hannah Bailey", "email": "hannah.bailey@gmail.com" },
{ "name": "Christopher Bell", "email": "christopher.bell@outlook.com" },
{ "name": "Madison Murphy", "email": "madison.murphy@hotmail.com" },
{ "name": "Dylan Howard", "email": "dylan.howard@gmail.com" },
{ "name": "Layla Cox", "email": "layla.cox@yahoo.com" },
{ "name": "Ethan Ward", "email": "ethan.ward@icloud.com" },
{ "name": "Grace Brooks", "email": "grace.brooks@hotmail.com" },
{ "name": "Jackson Torres", "email": "jackson.torres@gmail.com" },
{ "name": "Victoria Sanders", "email": "victoria.sanders@outlook.com" }
]

# %%
all_emails = pd.DataFrame(columns=["customer_id", "order_id", "products", "email", "customer_name", "email_address"])

for i in range(51):
    customer_id = customers["customer_id"].values[i]
    print(customer_id)
    customer_order_info = orders[orders["customer_id"] == customer_id][['order_id', 'customer_id', 'order_purchase_timestamp',
       'order_approved_at','order_estimated_delivery_date']]
    order_id = customer_order_info["order_id"].values.tolist()[0]
    order_time = customer_order_info["order_purchase_timestamp"].values.tolist()[0]
    customer_order_items = order_items[order_items["order_id"] == order_id]
   #  customer_payment_info = order_payment[order_payment["order_id"] == order_id]
    products = customer_order_items["product_category_name_english"].values.tolist()


    prompt = """ Write a realistic email to customer support from """ + customer_name_email[i]["name"] + """ (""" + customer_name_email[i]["email"] +""") asking about the status of their order.
                 Which was ordered at  """ + order_time + """. Do not include a phone number.
                 Order number:  """ + order_id
    
    email = query_open_ai(prompt)

    new_email = pd.DataFrame([[customer_id, order_id, products, email, customer_name_email[i]["name"], customer_name_email[i]["email"]]], 
                             columns=["customer_id", "order_id", "products", "email", "customer_name", "email_address"])
    all_emails = pd.concat([all_emails, new_email])
# Out:
# 1be70cd84bb8fdc5c77a52054d6250f8
# a8efde73814dc81ff114f0980fb6386f
# 46e7342ce409f2b5656f102f2ba9b9dc
# 65060b85a336b487c0fe7d42d64b3b99
# 73a8c93b316350e98f0d0804293f2c27
# eb58af3f31ba5d587163397ba551e188
# af6b5c7327d3dc4e1c212fa747706713
# 9babe15f3a8d05c3ae49e0e57faa9588
# 86d44d270b72592dbef78de27ec82d08
# 6b58b82f79f4f6d4b1663dbc9824ce15
# adfd5b68ee720910253520bfcf6b3b1a
# 6fd5c621e78c434aa741e9ffb9c68250
# b26b21a6be03433cf3052ee4b22a69c3
# cacf236a67a1b018693b6e7309a3f670
# 84055878b8547a9f9944a8108146cf4f
# 9b684ecb3042a93d9476416aa979f289
# cda5f27136ac1f174e1ba59d0bfea170
# 60be07ae31950ebb5bb4c2202837abc9
# d3c3354f609a1a80b78fbab8d5435061
# a10bf76efea959603e21cbfc13bbf221
# 64cd9338d3ef094dd406d660f738e7e3
# cff21f454392b393d14858896b612102
# 1c2892b86921932bc4c4ac3045481688
# 3506351d6f6e36e9b381d2cbd40000b0
# ed7abe2bf6dacb66b55c2bebf0d2adaf
# a582b5b6122b059b61fd2151d0ed11fd
# e92e2b7d6b397c76ae6dbbc5b351e9cf
# 431aa8450d30ae25badcaf4186f88281
# 9044dc01c6e9883f46c56c147c6c61f5
# 3e7b2479252ab3087413e44eb3354263
# 6e53638ba966c41af8fc2b198caa69a3
# 20a63f927ff449c4b0c0a3c03b91766a
# 1e11025f8a103ddbf95ddaca105f7f4a
# 836760dcb82c039d393284e02bf6d7c3
# e25778ef22bc9a95b7b57e0d133ba1af
# 10774c3bd46abb71735156fc85b987c4
# 31cb67b7313db83a08d6aa86d1eef8ac
# 42a99ab9bfd1b17172c9d6a31e4958c8
# 8209a3936175e3005c195b126952c392
# 94681622e0ad228d6c238a15aa9441fa
# 6ad71323c11ba8a83737ccc3ea31fbc3
# f8cd59b49dad40a126346bd2da7649c5
# b76d67086136493ca1369feae3f5cf2e
# ae5a8b3960da2fabebd3e52971ee961c
# c8660ee878b885629d78660691d2e8a7
# 7dcf62c05f6540b1515ae11c74d6d6b1
# 1a6cb0e076784a5e73557aa5defd660a
# 7fe022d44964a339398a981ce3026ea7
# 5265029daa29cc08d86b9f96cd99d03f
# 5c40be15b2c8fc641d9a1fc0493ac2bf
# dd20dff57e18e1c1fbff44235906d1e2

# %%
for email in all_emails["email"].reset_index(drop=True):
    print(email)
    print("")
# Out:
# Subject: Inquiry About Order Status - Order #9b1c817fd98473c0a0dab2a95b5979a6
#
# Dear Customer Support Team,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on August 6, 2017. The order number is 9b1c817fd98473c0a0dab2a95b5979a6.
#
# As it has been some time since I placed the order, I am eager to know the current status and estimated delivery date. I would appreciate any updates you could provide regarding this order.
#
# Please let me know if there is any additional information you need from my side to facilitate this inquiry.
#
# Thank you for your assistance.
#
# Best regards,
#
# John Smith
# john.smith@gmail.com
#
# Subject: Inquiry About Order Status - Order #d242f228c4dd03301794ded8f02dce54
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on April 19, 2018, with the order number d242f228c4dd03301794ded8f02dce54. It has been some time since I placed the order, and I have not yet received any updates regarding its shipment or delivery.
#
# Could you please provide me with the current status of my order? I would appreciate any information you can offer regarding its expected delivery date or any potential delays.
#
# Thank you for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Jane Doe
# jane.doe@yahoo.com
#
# Subject: Inquiry About Order Status - Order #c67eb6f352d61cbfeec214480d5c6baf
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my order placed on June 29, 2018, at 21:05:36. The order number is c67eb6f352d61cbfeec214480d5c6baf.
#
# I have not yet received any updates regarding the shipment or delivery of my order and would greatly appreciate any information you could provide. If there are any issues or delays, please let me know so that I can adjust my plans accordingly.
#
# Thank you in advance for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Alice Johnson
# alice.johnson@outlook.com
#
# Subject: Inquiry About Order Status - Order #5e5c29987bbb83ed38c9b25a753f978f
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on May 29, 2017, at 10:01:22 AM. The order number is 5e5c29987bbb83ed38c9b25a753f978f.
#
# It has been some time since I placed the order, and I have not received any updates regarding its shipment or expected delivery date. I would appreciate it if you could provide me with an update on the current status of my order and any relevant tracking information.
#
# Please let me know if there are any issues or delays that I should be aware of, and if there is anything I can do to expedite the process.
#
# Thank you for your prompt attention to this matter. I look forward to your response.
#
# Best regards,
#
# Robert Brown
# robert.brown@gmail.com
#
# Subject: Inquiry About Order Status - Order #db9564d23d5d0d213eb2a0b5ca279c2f
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order, placed on August 10, 2017, at 6:45 PM. The order number is db9564d23d5d0d213eb2a0b5ca279c2f.
#
# I have not yet received any updates regarding the shipment or delivery of this order, and I am eager to know when I can expect it to arrive. Could you please provide me with an update on the current status of my order?
#
# Thank you for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Emily Davis
# emily.davis@hotmail.com
#
# Subject: Inquiry About Order Status - Order #48679e7a18e6aa746943453400b7e74c
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my order placed on February 26, 2018, with the order number 48679e7a18e6aa746943453400b7e74c.
#
# I have not received any updates regarding the shipment or delivery of my order, and I would appreciate it if you could provide me with an update on its current status. If there are any issues or delays, please let me know so we can address them promptly.
#
# Thank you for your attention to this matter. I look forward to your prompt response.
#
# Best regards,
#
# Michael Wilson
# michael.wilson@yahoo.com
#
# Subject: Inquiry About Order Status - Order #1cee73866d7513dbc499639d14020ce4
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on July 24, 2017, at 12:52 PM. The order number is 1cee73866d7513dbc499639d14020ce4.
#
# As it has been some time since I placed the order, I am curious to know if there have been any updates regarding its processing or shipment. I would appreciate any information you could provide about when I might expect to receive my order.
#
# Thank you for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Sarah Martinez
# sarah.martinez@gmail.com
#
# Subject: Inquiry About Order Status - Order #c76a06605f09c1a1e5cf90bea47a528f
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on June 19, 2017. The order number is c76a06605f09c1a1e5cf90bea47a528f.
#
# I have not received any updates regarding the shipment or delivery, and I would appreciate any information you can provide about its current status. If there are any issues or delays, please let me know how I can assist in resolving them.
#
# Thank you for your attention to this matter. I look forward to your prompt response.
#
# Best regards,
#
# David Anderson
# david.anderson@icloud.com
#
# Subject: Inquiry About Order Status - Order #cdb67b9f52b1b7cd79169a5aae48d7c2
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on March 7, 2018, at 12:04:58 PM. The order number is cdb67b9f52b1b7cd79169a5aae48d7c2.
#
# I have not yet received any updates regarding the shipment or delivery of my order and would appreciate any information you could provide. Could you please let me know the current status and estimated delivery date?
#
# Thank you for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Emma Thomas
# emma.thomas@aol.com
#
# Subject: Inquiry Regarding Order Status - Order #b43e5b62115893759c15e7e9c96cb25b
#
# Dear Customer Support Team,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order, placed on May 23, 2017, at 21:42:40. The order number is b43e5b62115893759c15e7e9c96cb25b.
#
# I have not yet received any updates regarding the shipment or delivery of this order and would appreciate any information you could provide on its current status. Understanding the expected delivery timeline would be very helpful.
#
# Thank you for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# James White
# james.white@outlook.com
#
# Subject: Inquiry About Order Status - Order #5462150a55227cc8cba846f26101492e
#
# Dear Customer Support Team,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on December 2, 2017, at 15:25:55. The order number is 5462150a55227cc8cba846f26101492e.
#
# It has been some time since I placed the order, and I have yet to receive any updates regarding its shipment or delivery status. I would appreciate it if you could provide me with an update on when I might expect to receive my order.
#
# Please let me know if there are any issues or delays that I should be aware of. I look forward to your prompt response and any assistance you can provide in resolving this matter.
#
# Thank you for your attention to this matter.
#
# Best regards,
#
# Olivia Harris
# olivia.harris@gmail.com
#
# Subject: Inquiry About Order Status - Order #24464b3dfd623dbde6ceb96af55eba7e
#
# Dear Customer Support,
#
# I hope this message finds you well. My name is William Martin, and I am writing to inquire about the status of my recent order placed on June 9, 2018, at 16:04:38. The order number is 24464b3dfd623dbde6ceb96af55eba7e.
#
# Unfortunately, I have not yet received any updates regarding the shipping or estimated delivery date. I would appreciate it if you could provide me with an update on the current status of my order.
#
# If there are any issues or delays, please let me know as soon as possible. I am eager to receive the items and would appreciate any assistance you can provide.
#
# Thank you for your attention to this matter. I look forward to your prompt response.
#
# Best regards,
#
# William Martin
# william.martin@yahoo.com
#
# Subject: Inquiry About Order Status - Order #df7301747236cf5a68212214f64959ca
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on June 7, 2017, at 14:10:04. The order number is df7301747236cf5a68212214f64959ca.
#
# I have not received any updates regarding the shipment or delivery of this order and wanted to ensure that everything is proceeding as expected. Could you please provide me with the current status of the order and an estimated delivery date?
#
# Thank you for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Sophia Thompson
# sophia.thompson@hotmail.com
#
# Subject: Inquiry About Order Status - Order No. bc03012724b4db8837684e376b6eeacd
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on June 16, 2018, at 20:50:28. The order number is bc03012724b4db8837684e376b6eeacd.
#
# I have not yet received any updates regarding the shipment or estimated delivery date, and I am keen to know when I might expect the order to arrive.
#
# Could you please provide me with an update on the status of my order? Additionally, if there are any issues or delays, I would appreciate any information on how they can be resolved.
#
# Thank you for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Benjamin Garcia
# benjamin.garcia@icloud.com
#
# Subject: Inquiry About Order Status - Order #d3cd9432f1869452249ac839d04a7964
#
# Dear Customer Support Team,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on May 7, 2018, at 11:20:02 AM. The order number is d3cd9432f1869452249ac839d04a7964.
#
# I have not yet received any updates regarding the shipment or delivery of this order, and I am eager to know when I can expect it to arrive. Could you please provide me with an update on its current status? If there are any issues or delays, I would appreciate it if you could inform me as soon as possible.
#
# Thank you for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Charlotte Martinez
# charlotte.martinez@gmail.com
#
# Subject: Inquiry About Order Status - Order #a7d6efcf25cbcbce23dbef446eb827d6
#
# Dear Customer Support Team,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on February 17, 2018, at 10:04:31 AM. The order number is a7d6efcf25cbcbce23dbef446eb827d6.
#
# As it has been some time since the order was placed, I am eager to know the current status and the expected delivery date. Any updates you can provide would be greatly appreciated.
#
# Thank you for your assistance, and I look forward to your prompt response.
#
# Best regards,
#
# Daniel Robinson
# daniel.robinson@outlook.com
#
# Subject: Inquiry About Order Status - Order #7b072cb297a1526bf0dcd28d61c6004d
#
# Dear Customer Support Team,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on March 18, 2018, at 1:46 PM. The order number is 7b072cb297a1526bf0dcd28d61c6004d.
#
# I have not yet received any updates regarding the shipping or delivery of my order and would appreciate any information you could provide on its current status. If there are any issues or delays, please let me know how they might be resolved.
#
# Thank you for your assistance and I look forward to hearing from you soon.
#
# Best regards,
#
# Mia Clark
# mia.clark@yahoo.com
#
# Subject: Inquiry About Order Status - Order #2d3518f1b535de87ccf593d3892022af
#
# Dear Customer Support Team,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on March 1, 2018, at 10:21:56 AM. The order number is 2d3518f1b535de87ccf593d3892022af.
#
# I have not yet received any updates regarding the shipment or delivery of my order, and I am eager to know when I might expect it to arrive. If there are any issues or delays, please let me know so that I can make necessary arrangements.
#
# Thank you for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Lucas Rodriguez
# lucas.rodriguez@gmail.com
#
# Subject: Inquiry About Order Status - Order #27b6bbf4efdd3d4aa75ead8d62a9088c
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my order, which I placed on June 2, 2017, at 11:33:10. The order number is 27b6bbf4efdd3d4aa75ead8d62a9088c.
#
# I have not received any updates regarding the shipment or delivery timeline since the order was placed. I would appreciate it if you could provide me with an update on the current status of my order, including any estimated delivery dates or potential delays.
#
# Thank you for your assistance in this matter. I look forward to your prompt response.
#
# Best regards,
#
# Amelia Lewis
# amelia.lewis@icloud.com
#
# Subject: Inquiry About Order Status - Order #96139d82556aff8edd1cfcfdc11a632b
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on September 21, 2017, at 19:19:32. The order number is 96139d82556aff8edd1cfcfdc11a632b.
#
# I have not yet received any updates regarding the shipment or delivery of this order. Could you please provide me with an update on its status? I would appreciate any tracking information or estimated delivery date you can provide.
#
# Thank you for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Henry Walker
# henry.walker@outlook.com
#
# Subject: Inquiry About Order Status - Order #50ce8749a5de60da0378aedfa46c1e6d
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order, placed on September 10, 2017, at 16:58:59. The order number is 50ce8749a5de60da0378aedfa46c1e6d.
#
# I have not yet received any updates regarding the shipment or delivery of this order. Could you please provide me with an update on its status? If there are any issues or delays, I would appreciate any information you can provide to help me understand the situation better.
#
# Thank you for your assistance, and I look forward to your prompt response.
#
# Best regards,
#
# Evelyn Hall
# evelyn.hall@gmail.com
#
# Subject: Inquiry About Order Status - Order #1f97eb43070457cfac15e2d29e13e855
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of an order I placed on January 11, 2018, at 10:29:59. The order number is 1f97eb43070457cfac15e2d29e13e855.
#
# I have not yet received any updates regarding the shipment or delivery of this order, and I am eager to know its current status. Could you please provide me with any available information regarding this order, including estimated delivery times?
#
# I appreciate your assistance and look forward to your prompt response.
#
# Thank you for your help.
#
# Best regards,
#
# Alexander Allen
# alexander.allen@hotmail.com
#
# Subject: Inquiry About Order Status - Order #c22b21487688078371d7c2a9ee2d04c3
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on May 21, 2017, at 11:23:41 AM. The order number is c22b21487688078371d7c2a9ee2d04c3.
#
# As it has been some time since the order was placed, I would appreciate an update on its status. Could you please let me know if there have been any delays or if there is an estimated delivery date? I am eager to receive the items and would like to plan accordingly.
#
# Thank you for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Harper Young
# harper.young@yahoo.com
#
# Subject: Inquiry About Order Status - #830189cecc91f11c9dd9405976aa5538
#
# Dear Customer Support Team,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order, placed on July 7, 2017, at 22:46:53. The order number is 830189cecc91f11c9dd9405976aa5538.
#
# I have not yet received any updates regarding the shipment or delivery of my order, and I am eager to know when I might expect it to arrive. I would appreciate it if you could provide me with an update on the current status or any available tracking information.
#
# Thank you for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Elijah King
# elijah.king@gmail.com
#
# Subject: Inquiry About Order Status - Order #dda3e0dbde3a2cd09432650b3634582d
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my order placed on April 22, 2018, at 8:13 PM. The order number is dda3e0dbde3a2cd09432650b3634582d.
#
# I understand that sometimes delays can occur, but I have not yet received any updates regarding the shipment or delivery of my order. I would appreciate it if you could provide me with the current status and an estimated delivery date.
#
# Thank you for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Isabella Wright
# isabella.wright@icloud.com
#
# Subject: Inquiry About Order Status - Order #219d7856c8969f8f7087ffe19ae28a36
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on July 22, 2018, with the order number 219d7856c8969f8f7087ffe19ae28a36.
#
# It's been some time since the order was placed, and I have yet to receive any updates regarding its shipment or delivery. I would appreciate it if you could provide me with an update on the current status of the order. Additionally, if there are any issues or delays, I would be grateful for any information on how they might be resolved.
#
# Thank you for your attention to this matter. I look forward to your prompt response.
#
# Best regards,
#
# Sebastian Scott
# sebastian.scott@aol.com
#
# Subject: Inquiry About Order Status - Order #bd6a23b926eaaee84f90244b9bcb12ac
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on August 10, 2018, at 10:10 AM. The order number is bd6a23b926eaaee84f90244b9bcb12ac.
#
# As it has been some time since the order was placed, I am eager to know its current status and estimated delivery date. I would appreciate any updates you can provide regarding the shipment and tracking details.
#
# Thank you for your attention to this matter. I look forward to your prompt response so I can plan accordingly.
#
# Best regards,
#
# Avery Green
# avery.green@yahoo.com
#
# Subject: Inquiry About Order Status - Order #8e1e1daffbcfac661558e71878b2780c
#
# Dear Customer Support Team,
#
# I hope this message finds you well. I am writing to inquire about the status of my order placed on February 1, 2018, at 12:22:13 PM. The order number is 8e1e1daffbcfac661558e71878b2780c.
#
# I understand that it has been quite some time since the order was placed, and I have not yet received any updates regarding its processing or shipping status. Could you please provide me with the current status of this order? Any information you can provide would be greatly appreciated.
#
# Thank you for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Jack Adams
# jack.adams@gmail.com
#
# Subject: Inquiry About Order Status - Order #3ef63bbc5cfb1ac8a9454f5c5e29b1cf
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on August 7, 2017, at 10:55:34 AM. The order number is 3ef63bbc5cfb1ac8a9454f5c5e29b1cf.
#
# I have not yet received any updates regarding the shipping or delivery of this order, and I am eager to know when I might expect it to arrive. Could you please provide me with any available information regarding the current status of this order?
#
# Thank you very much for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Lily Nelson
# lily.nelson@outlook.com
#
# Subject: Inquiry About Order Status - Order #a9cd6c2b2f5fb42940c49246ea7ce08f
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on February 2, 2018, at 11:14 AM. The order number is a9cd6c2b2f5fb42940c49246ea7ce08f.
#
# As it has been some time since the order was placed, I am eager to know when I might expect its delivery. I would appreciate any updates or information you could provide regarding its current status.
#
# Thank you very much for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Matthew Baker
# matthew.baker@hotmail.com
#
# Subject: Inquiry About Order Status - Order #c9d79a65d54550450dac1a0a08b71956
#
# Dear Customer Support Team,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on June 6, 2017, at 14:44:07. The order number is c9d79a65d54550450dac1a0a08b71956.
#
# As it has been some time since the order was placed, I am eager to know its current status and estimated delivery date. Any updates you could provide would be greatly appreciated.
#
# Thank you for your assistance, and I look forward to your prompt response.
#
# Best regards,
#
# Scarlett Gonzalez
# scarlett.gonzalez@yahoo.com
#
# Subject: Inquiry About Order Status - Order #7a91897e9a963e01419698c8927c4a31
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on December 19, 2017, at 17:08:14. The order number is 7a91897e9a963e01419698c8927c4a31.
#
# As I have not received any updates regarding the shipment or delivery date, I would appreciate it if you could provide me with the current status of my order. Additionally, if there are any issues or delays, please let me know how they might affect the expected delivery timeline.
#
# Thank you for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Joseph Carter
# joseph.carter@gmail.com
#
# Subject: Inquiry About Order Status - Order #8f627f546b2cb0ddbb0d8627461b846f
#
# Dear Customer Support,
#
# I hope this message finds you well. I'm writing to inquire about the status of my order, which I placed on March 15, 2018, at 3:20 PM. The order number is 8f627f546b2cb0ddbb0d8627461b846f.
#
# It's been quite some time since I placed the order, and I haven't received any updates or notifications regarding its shipment or delivery. Could you please provide me with an update on the current status of my order? I would appreciate any information you can give me about its expected delivery date or any issues that might be causing a delay.
#
# Thank you for your attention to this matter. I look forward to your prompt response.
#
# Best regards,
#
# Chloe Perez
# chloe.perez@icloud.com
#
# Subject: Inquiry on Order Status - Order #edd96b4f322cd7181741044d2e016158
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order, which was placed on May 5, 2018, at 18:28:19. The order number is edd96b4f322cd7181741044d2e016158.
#
# As it has been some time since the order was placed, I wanted to check in and see if there are any updates regarding its processing or shipping. I would appreciate any information you can provide on the expected delivery date or any potential delays.
#
# Thank you for your assistance, and I look forward to your prompt response.
#
# Best regards,
#
# Samuel Turner
# samuel.turner@hotmail.com
#
# Subject: Inquiry About Order Status - Order #a9b67aa415d798b812b40a140b942486
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on November 24, 2017, with the order number a9b67aa415d798b812b40a140b942486. I understand that it may take some time to process and ship orders, but I would appreciate any updates you can provide regarding the expected delivery date.
#
# If there are any issues or additional information required from my side to expedite the process, please do not hesitate to let me know. I am eager to receive the items and hope everything is on track.
#
# Thank you for your assistance and support.
#
# Best regards,
#
# Zoey Collins
# zoey.collins@yahoo.com
#
# Subject: Inquiry About Order Status - Order #a7e6fba3426b2524d4ae03c6bcd147ee
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on November 20, 2017, at 22:30:23. The order number is a7e6fba3426b2524d4ae03c6bcd147ee.
#
# I understand that some time has passed since the order was placed, and I have not yet received any updates regarding its processing or shipment. Could you please provide me with the current status of my order? Additionally, if there are any issues or delays, I would appreciate any information on how they might be resolved.
#
# Thank you for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# David Edwards
# david.edwards@gmail.com
#
# Subject: Inquiry About Order Status - Order #29f4481c82fe8804ae3de770fd4012aa
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on July 24, 2018, at 12:56:11 PM. The order number is 29f4481c82fe8804ae3de770fd4012aa.
#
# I have not yet received any updates regarding the shipment or estimated delivery date, and I am eager to know when I can expect the order to arrive.
#
# Could you please provide me with an update on the status of my order? I would appreciate any tracking information or expected delivery time frame that you can share.
#
# Thank you for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Ella Stewart
# ella.stewart@aol.com
#
# Subject: Inquiry About Order Status - Order #915a913fc05ab382dafb7776ea8c9580
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my order placed on November 26, 2017, at 18:28:51. The order number is 915a913fc05ab382dafb7776ea8c9580.
#
# It has been some time since I placed the order, and I have not yet received any updates regarding its shipment or expected delivery date. I would appreciate it if you could provide me with any available information regarding the current status of my order.
#
# Thank you for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Gabriel Flores
# gabriel.flores@outlook.com
#
# Subject: Inquiry About Order Status - Order #ec6ec630f8a398e0da49ca915969bffa
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on April 4th, 2018 at 17:24:24. The order number is ec6ec630f8a398e0da49ca915969bffa.
#
# As I have not yet received any updates regarding the shipping or delivery of my order, I would appreciate it if you could provide me with the current status. I am particularly eager to know when I can expect to receive my package, as the anticipated delivery date has passed.
#
# Thank you for your assistance in this matter. I look forward to your prompt response.
#
# Best regards,
#
# Aria Morris
# aria.morris@gmail.com
#
# Subject: Inquiry About Order Status: c0985d645958d6bf06fda4f4287bfe90
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order, placed on February 17, 2018, at 10:35:46 AM. The order number is c0985d645958d6bf06fda4f4287bfe90.
#
# It has been some time since I placed the order, and I have not yet received any updates regarding its shipment or estimated delivery date. I would appreciate it if you could provide me with any available information on the current status of my order.
#
# Thank you for your attention to this matter. I look forward to your prompt response.
#
# Best regards,
#
# Nathaniel Rivera
# nathaniel.rivera@icloud.com
#
# Subject: Inquiry About Order Status - Order #69fd81b0cd556f5da5000c1ed874ed19
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on September 25, 2017, at 10:53:40 AM. The order number is 69fd81b0cd556f5da5000c1ed874ed19.
#
# I have not yet received any updates regarding the shipping or delivery of my order, and I am eager to know when I can expect it to arrive. Could you please provide me with an update on the current status of this order?
#
# I appreciate your assistance and look forward to your prompt response.
#
# Thank you very much.
#
# Best regards,
#
# Penelope Cooper
# penelope.cooper@hotmail.com
#
# Subject: Inquiry About Order Status - Order #d805508e2cdf3a5b1453bc2eb0371880
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on July 23, 2018, with the order number d805508e2cdf3a5b1453bc2eb0371880.
#
# It has been some time since the order was placed, and I have not yet received any updates regarding its shipment or delivery. I would appreciate it if you could provide me with the current status of the order and an estimated delivery date.
#
# Thank you for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Andrew Reed
# andrew.reed@yahoo.com
#
# Subject: Inquiry About Order Status - Order #7b57eaf2caa8c4844ecceaca731c93fe
#
# Dear Customer Support Team,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on July 16, 2018. The order number is 7b57eaf2caa8c4844ecceaca731c93fe.
#
# I have not yet received any updates regarding the shipping or delivery of my order. I would appreciate it if you could provide me with an update on its current status and an estimated delivery date.
#
# Thank you for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Hannah Bailey
# hannah.bailey@gmail.com
#
# Subject: Inquiry About Order Status - Order #2e5763acace24933483420e74a222c5e
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on August 8, 2017, at 17:22:23. The order number is 2e5763acace24933483420e74a222c5e.
#
# I have not yet received any updates regarding the shipment or delivery of my order and would appreciate any information you can provide on its current status. Could you please let me know if there are any delays or issues with my order?
#
# Thank you in advance for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Christopher Bell
# christopher.bell@outlook.com
#
# Subject: Inquiry About Order Status - Order #cef8a99d7dd7e35db1b3211b258b6550
#
# Dear Customer Support Team,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on November 24, 2017, at 18:23:13. The order number is cef8a99d7dd7e35db1b3211b258b6550.
#
# I have not yet received any updates on the shipping status, and I am eager to know when I might expect delivery. If there are any issues or delays, please let me know so we can address them promptly.
#
# Thank you for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Madison Murphy
# madison.murphy@hotmail.com
#
# Subject: Inquiry About Order Status - Order #d41cca426db55a5cffe764e4ebfc5527
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on July 27, 2017, at 21:50:45. The order number is d41cca426db55a5cffe764e4ebfc5527.
#
# I have not received any updates regarding the shipment or delivery details, and I am eager to know when I can expect the order to arrive. Could you please provide me with the current status of my order and any relevant tracking information?
#
# Thank you for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Dylan Howard
# dylan.howard@gmail.com
#
# Subject: Inquiry About Order Status - Order #8650f273b9279f880588142245c2c398
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the current status of my order placed on June 22, 2017, at 11:05 AM. The order number is 8650f273b9279f880588142245c2c398.
#
# As it has been some time since the order was placed, I wanted to confirm whether it has been processed and shipped. If possible, could you please provide an estimated delivery date? I am eager to receive the items and would appreciate any updates you can provide.
#
# Thank you for your assistance and looking forward to your prompt response.
#
# Best regards,
#
# Layla Cox
# layla.cox@yahoo.com
#
# Subject: Inquiry About Order Status - Order #b1adda8b2734d4a0bae4885a90722859
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of an order I placed on January 21, 2018, with the order number b1adda8b2734d4a0bae4885a90722859.
#
# I understand that it has been quite some time since the order was placed, and I am eager to know if there have been any updates regarding shipment or delivery. If there are any issues or delays, please let me know how they can be resolved.
#
# I appreciate your assistance and look forward to hearing from you soon.
#
# Thank you in advance for your help.
#
# Best regards,
#
# Ethan Ward
# ethan.ward@icloud.com
#
# Subject: Inquiry About Order Status - Order #2b72a32a2c3e93fa260ca7655073886f
#
# Dear Customer Support Team,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on April 18, 2018, at 15:40:36. The order number is 2b72a32a2c3e93fa260ca7655073886f.
#
# As it has been some time since I placed the order, I am eager to know if there have been any updates regarding its processing and estimated delivery date. I would appreciate any information you could provide me regarding this order.
#
# Thank you for your assistance. I look forward to your prompt response.
#
# Best regards,
#
# Grace Brooks
# grace.brooks@hotmail.com
#
# Subject: Inquiry on Order Status - Order #09ab8a3234b24017600673c296756fdf
#
# Hi Customer Support Team,
#
# I hope this message finds you well. I am writing to inquire about the status of my order placed on January 22, 2018, with the order number 09ab8a3234b24017600673c296756fdf.
#
# I understand that processing times can vary, but as it has been some time since the order was placed, I wanted to check in for any updates regarding its status or estimated delivery date.
#
# If there are any issues or additional information required from my end to facilitate the process, please let me know. I'm looking forward to hearing from you soon.
#
# Thank you for your assistance.
#
# Best regards,
#
# Jackson Torres
# jackson.torres@gmail.com
#
# Subject: Inquiry About Order Status - Order #1dcb629bf4ae95dddc7ec77ff8fcdd4a
#
# Dear Customer Support,
#
# I hope this message finds you well. I am writing to inquire about the status of my recent order placed on January 30, 2018, at 11:17:47 AM. The order number is 1dcb629bf4ae95dddc7ec77ff8fcdd4a.
#
# I have not yet received any updates regarding the shipping or delivery of the order, and I am eager to know when I might expect it to arrive. If there are any issues or delays, I would appreciate your assistance in resolving them.
#
# Please let me know if you need any further information from my end to help expedite the process.
#
# Thank you for your attention to this matter.
#
# Best regards,
#
# Victoria Sanders
# victoria.sanders@outlook.com

# %%
# all_emails["category"] = "Order Status"

# all_emails[['customer_id', 'order_id', 'email', 'customer_name','email_address', 'category']].to_csv(data_folder + 'order_status_emails.csv')

# %%
all_emails = pd.read_csv(data_folder + 'order_status_emails.csv')

# %%
all_emails.head()
# Out:
#    Unnamed: 0                       customer_id  \
# 0           0  1be70cd84bb8fdc5c77a52054d6250f8
# 1           0  a8efde73814dc81ff114f0980fb6386f
# 2           0  46e7342ce409f2b5656f102f2ba9b9dc
# 3           0  65060b85a336b487c0fe7d42d64b3b99
# 4           0  73a8c93b316350e98f0d0804293f2c27
#
#                            order_id  \
# 0  9b1c817fd98473c0a0dab2a95b5979a6
# 1  d242f228c4dd03301794ded8f02dce54
# 2  c67eb6f352d61cbfeec214480d5c6baf
# 3  5e5c29987bbb83ed38c9b25a753f978f
# 4  db9564d23d5d0d213eb2a0b5ca279c2f
#
#                                                email  customer_name  \
# 0  Subject: Inquiry About Order Status - Order #9...     John Smith
# 1  Subject: Inquiry About Order Status - Order #d...       Jane Doe
# 2  Subject: Inquiry About Order Status - Order #c...  Alice Johnson
# 3  Subject: Inquiry About Order Status - Order #5...   Robert Brown
# 4  Subject: Inquiry About Order Status - Order #d...    Emily Davis
#
#                email_address      category
# 0       john.smith@gmail.com  Order Status
# 1         jane.doe@yahoo.com  Order Status
# 2  alice.johnson@outlook.com  Order Status
# 3     robert.brown@gmail.com  Order Status
# 4    emily.davis@hotmail.com  Order Status

# %%
timestamps =[]
for index, row in all_emails.iterrows():
    customer_id = row["customer_id"]
    order_id = row["order_id"]
    email = row["email"]
    order_info = orders[(orders["customer_id"].astype(str) == str(customer_id)) & (orders["order_id"].astype(str) == str(order_id))]

    prompt = """ Determine when this email might have been sent. Based on the on this email: """ + email + """

                 And this order information  """ + order_info.to_json() + """. When might this email have been sent.  
                 Return only the timestamp in the format 'year-month-date hour:minute:second'. 
                 Do not return any additional information. Only return the timestamp.""" 
    
    time = query_open_ai(prompt)
    timestamps += [time]

# %%
all_emails["email_recieved"] = pd.DataFrame(timestamps)

# %%
all_emails.columns
# Out:
# Index(['Unnamed: 0', 'customer_id', 'order_id', 'email', 'customer_name',
#        'email_address', 'category', 'email_recieved'],
#       dtype='object')

# %%
# all_emails[[ 'customer_id', 'order_id', 'email', 'customer_name',
#        'email_address', 'category', 'email_recieved']].to_csv(data_folder + 'order_status_emails.csv')
